# %% [markdown]
# # DATA VISUALIZATION : IRIS DATA SET

# %%
#load necessary packages for basic algebra and data processing of files.

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#upload data from url 
#Get a look at the dataset 
#Label the columns 

url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
cols = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Class']
iris_data = pd.read_csv(url, names=cols)
iris_data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm        Class
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_data.describe
# Out:
# <bound method NDFrame.describe of      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm           Class
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# 5              5.4           3.9            1.7           0.4     Iris-setosa
# 6              4.6           3.4            1.4           0.3     Iris-setosa
# 7              5.0           3.4            1.5           0.2     Iris-setosa
# 8              4.4           2.9            1.4           0.2     Iris-setosa
# 9              4.9           3.1            1.5           0.1     Iris-setosa
# 10             5.4           3.7            1.5           0.2     Iris-setosa
# ...

# %% [markdown]
# ### DATA VISUALISATION

# %%
#A Pair Plot 

import seaborn as sns; sns.set(style="ticks", color_codes=True)
g = sns.pairplot(iris_data)

# %%
g = sns.pairplot(iris_data, hue="Class")

# %%
#using different colors 
#My favourite colors 

g = sns.pairplot(iris_data, hue="Class", palette="husl")

# %%
#using different markers for each class for easier analysis 

g = sns.pairplot(iris_data, hue="Class", markers=["o", "s", "D"])

# %%
sns.FacetGrid(iris_data, hue="Class", size=5) \
    .map(plt.scatter, "SepalLengthCm", "SepalWidthCm") \
    .add_legend()

# %%
sns.FacetGrid(data, hue="Class", size=5) \
    .map(plt.scatter, "PetalLengthCm", "PetalWidthCm") \
    .add_legend()

# %%
sns.FacetGrid(data, hue="Class", size=5) \
    .map(plt.scatter, "PetalLengthCm", "SepalLengthCm") \
    .add_legend()

# %%
sns.FacetGrid(data, hue="Class", size=5) \
    .map(plt.scatter, "PetalWidthCm", "SepalWidthCm") \
    .add_legend()

# %%
#Seaborn allows us to plot joint plots i.e scatterplots and histograms

sns.jointplot(x="SepalLengthCm", y="SepalWidthCm", data=iris_data, size=5)

# %%
#Ploting a regression line with all the different classes
sns.lmplot(x='SepalLengthCm',y='SepalWidthCm',data=iris_data)
sns.lmplot(x='SepalLengthCm',y='SepalWidthCm',data=iris_data,hue='Class')
sns.residplot(x='SepalLengthCm',y='SepalWidthCm',data=iris_data)

# %%
#Regression Line of each species separately

sns.lmplot(x='SepalLengthCm',y='SepalWidthCm',data=iris_data,hue='Class',col='Class')
